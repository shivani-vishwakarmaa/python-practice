# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani-vishwakarmaa/python-practice/blob/main/All_List_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """
# # 🔢 Python List Methods Notebook
#
# ✅ This notebook demonstrates 15+ list methods in Python.
# Each method is:
#
# - 💡 Explained with a simple code example
# - 🧪 Run individually using `# @title` headers
# - 🧠 Great for learning or interview prep
#
# **How to Use:**
# - ▶️ Run each cell to see what it does
# - 📝 Modify the list to try variations
# """

# %%
# @title append()
my_list = [1, 2, 3]
my_list.append(4)
my_list.append([7,9])

print(my_list)  # [1, 2, 3, 4]
# Out:
# [1, 2, 3, 4, [7, 9]]

# %%
# @title extend()
my_list = [1, 2, 3]
my_list.extend([4, 5])
print(my_list)  # [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# @title insert()
#list.insert(index, element)

my_list = [1, 3, 4]
my_list.insert(1, 2)
print(my_list)  # [1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
# @title remove()
#Removes the first occurrence of the specified element. Raises ValueError if the element is not found.
my_list = [1, 2, 3, 2]
my_list.remove(2)
print(my_list)  # [1, 3, 2]

# %%
# in list
# @title pop()
my_list = [ 10,20, 30]
value = my_list.pop()
value1=my_list.pop(1)  # can specify index
print(value)     # 30
print(my_list)   # [10, 20]
# Out:
# 30
# [10]

# %%
# in set
s = {0,90,10, 20, 30}
value = s.pop()
print(value)     # 30
print(s)   # [10, 20]
# Out:
# 0
# {20, 90, 10, 30}

# %%
# @title clear()
my_list = [1, 2, 3]
my_list.clear()
print(my_list)  # []

# %%
# @title index()
my_list = [10, 20, 30]
print(my_list.index(20))  # 1

# %%
# @title count()
my_list = [1, 2, 2, 3]
print(my_list.count(2))  # 2

# %%
# @title sort()
my_list = [3, 1, 4, 2]
my_list.sort()
print(my_list)  # [1, 2, 3, 4]
my_list.sort(reverse=True)
print(my_list)  # [4, 3, 2, 1]

# %%
# @title reverse()
my_list = [1, 2, 3]
my_list.reverse()
print(my_list)  # [3, 2, 1]

# %%
# @title copy()
original = [1, 2, 3]
copy = original.copy()
print(copy)  # [1, 2, 3]

# %%
# @title len() on list
my_list = [10, 20, 30]
print(len(my_list))  # 3

# %%
# @title sum() on list
my_list = [1, 2, 3]
print(sum(my_list))  # 6
# Out:
# 6

# %%
# @title max() and min()
my_list = [5, 2, 9]
print(max(my_list))  # 9
print(min(my_list))  # 2
# Out:
# 9
# 2
